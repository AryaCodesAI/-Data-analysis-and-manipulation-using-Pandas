# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.

# %% [markdown]
# ### Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %% [markdown]
# ### Assign it to a variable called users.

# %%
import pandas as pd
df_users= pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', 
                      sep='|', index_col='user_id')
df_users
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %% [markdown]
# ### Discover what is the mean age per occupation

# %%
df_users.groupby('occupation').age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# ### Discover the Male ratio per occupation and sort it from the most to the least

# %%
df_users.groupby(['occupation', 'gender']).age.sum()
# Out:
# occupation     gender
# administrator  F         1463
#                M         1598
# artist         F          394
#                M          485
# doctor         M          305
# educator       F         1017
#                M         2974
# engineer       F           59
#                M         2379
# entertainment  F           62
#                M          464
# executive      F          132
#                M         1107
# healthcare     F          438
#                M          227
# homemaker      F          205
#                M           23
# lawyer         F           79
#                M          362
# librarian      F         1160
#                M          880
# marketing      F          372
#                M          606
# none           F          146
#                M           93
# other          F         1277
#                M         2348
# programmer     F          193
#                M         1993
# retired        F           70
# ...

# %%
df_users.groupby('occupation').gender.mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\miniconda3\lib\site-packages\pandas\core\groupby\groupby.py:1587, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1586 try:
# -> 1587     result = self.grouper._cython_operation(
#    1588         "aggregate", values, how, axis=data.ndim - 1, min_count=min_count
#    1589     )
#    1590 except NotImplementedError:
#    1591     # generally if we have numeric_only=False
#    1592     # and non-applicable functions
#    1593     # try to python agg
#    1594     # TODO: shouldn't min_count matter?
#
# File ~\miniconda3\lib\site-packages\pandas\core\groupby\ops.py:939, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     938 ngroups = self.ngroups
# --> 939 return cy_op.cython_operation(
#     940     values=values,
#     941     axis=axis,
# ...

# %% [markdown]
# ### For each occupation, calculate the minimum and maximum ages

# %%
data= {min : df_users.groupby('occupation').age.min(),
max : df_users.groupby('occupation').age.max()}
df_minmax = pd.DataFrame(data)
df_minmax
# Out:
#                <built-in function min>  <built-in function max>
# occupation
# administrator                       21                       70
# artist                              19                       48
# doctor                              28                       64
# educator                            23                       63
# engineer                            22                       70
# entertainment                       15                       50
# executive                           22                       69
# healthcare                          22                       62
# homemaker                           20                       50
# lawyer                              21                       53
# librarian                           23                       69
# marketing                           24                       55
# none                                11                       55
# ...

# %% [markdown]
# ### For each combination of occupation and gender, calculate the mean age

# %%
df_users.groupby(['occupation', 'gender']).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# ###  For each occupation present the percentage of women and men

# %%
df_users.groupby(['occupation', 'gender']).max()
# Out:
#                       age zip_code
# occupation    gender
# administrator F        62    V1G4L
#               M        70    M7A1A
# artist        F        48    V5A2B
#               M        45    98006
# doctor        M        64    97405
# educator      F        51    98103
#               M        63    M4J2K
# engineer      F        36    80228
#               M        70    T8H1N
# entertainment F        38    90814
#               M        50    V3N4P
# executive     F        49    90291
#               M        69    L1V3W
# healthcare    F        53    93555
#               M        62    97232
# homemaker     F        50    96349
#               M        23    61755
# lawyer        F        51    53202
#               M        53    90703
# librarian     F        59    97403
#               M        69    99603
# marketing     F        50    97215
#               M        55    97124
# none          F        55    90247
#               M        33    94619
# ...
